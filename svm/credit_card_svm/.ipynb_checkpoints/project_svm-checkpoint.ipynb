# %%
pip install pandas numpy scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/jihed/.local/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: numpy in /home/jihed/.local/lib/python3.11/site-packages (1.26.2)
# Requirement already satisfied: scikit-learn in /home/jihed/.local/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/jihed/.local/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in /home/jihed/.local/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/jihed/.local/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jihed/.local/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
# from sklearn.metrics import plot_confusion_matrix
from sklearn.decomposition import PCA

# %%
df=pd.read_csv(r'/home/jihed/projects/svm/default of credit card clients.tsv',header=1,sep='\t')

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
df.rename({'default payment next month':'DEFAULT'},axis='columns',inplace=True)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0        1
# 1      1000         0      2000        1
# 2      1000      1000      5000        0
# 3      1100      1069      1000        0
# 4      9000       689       679        0
#
# [5 rows x 25 columns]

# %%
df.drop('ID',axis='columns',inplace=True)
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0        1
# 1      1000         0      2000        1
# 2      1000      1000      5000        0
# 3      1100      1069      1000        0
# 4      9000       689       679        0
#
# [5 rows x 24 columns]

# %%
df.dtypes
# Out:
# LIMIT_BAL    int64
# SEX          int64
# EDUCATION    int64
# MARRIAGE     int64
# AGE          int64
# PAY_0        int64
# PAY_2        int64
# PAY_3        int64
# PAY_4        int64
# PAY_5        int64
# PAY_6        int64
# BILL_AMT1    int64
# BILL_AMT2    int64
# BILL_AMT3    int64
# BILL_AMT4    int64
# BILL_AMT5    int64
# BILL_AMT6    int64
# PAY_AMT1     int64
# PAY_AMT2     int64
# PAY_AMT3     int64
# PAY_AMT4     int64
# PAY_AMT5     int64
# PAY_AMT6     int64
# DEFAULT      int64
# dtype: object

# %%
df['SEX'].unique()
# Out:
# array([2, 1])

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0])

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
len(df.loc[(df['EDUCATION']==0 )| (df['MARRIAGE']==0)])
# Out:
# 68

# %%
len(df)
# Out:
# 30000

# %%
df_no_missing=df.loc[(df['EDUCATION']!=0 )& (df['MARRIAGE']!=0)]

# %%
len(df_no_missing)
# Out:
# 29932

# %%
df_no_default=df_no_missing[df_no_missing['DEFAULT']==0]
df_default=df_no_missing[df_no_missing['DEFAULT']==1]

# %%
    df_no_default_downsampled=resample(df_no_default,replace=False,n_samples=1000,random_state=42)
    len(df_no_default_downsampled)
# Out:
# 1000

# %%
df_default_downsampled=resample(df_default,replace=False,n_samples=1000,random_state=42)
len(df_default_downsampled)
# Out:
# 1000

# %%
df_downsample=pd.concat([df_no_default_downsampled,df_default_downsampled])
len(df_downsample)
# Out:
# 2000

# %%
X=df_downsample.drop('DEFAULT',axis=1).copy()
X.head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 641       130000    2          3         1   28      0      0      0      0
# 4678      170000    1          3         1   29      0      0      0      0
# 16004     180000    2          2         1   29      0      0      0      0
# 22974     210000    2          2         2   32     -2     -2     -2     -2
# 17535     190000    2          3         1   45      0      0      0      0
#
#        PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 641       -2  ...      50000          0          0          0      2500
# 4678       0  ...     172307      35234      32869      33862      7200
# 16004      0  ...      26310      26662      26166      26176      1800
# 22974     -2  ...        410          0          0          0       979
# 17535      0  ...      80548      81778      83082      84811      3300
#
#        PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 641        1000         0         0         0         0
# 4678       7500      1200      1200      1500      1300
# 16004      1800      1500      1056       950      1000
# 22974       412         0         0         0         0
# 17535      3331      3359      2663      2751      3000
#
# [5 rows x 23 columns]

# %%
y=df_downsample['DEFAULT'].copy()
y.head()
# Out:
# 641      0
# 4678     0
# 16004    0
# 22974    0
# 17535    0
# Name: DEFAULT, dtype: int64

# %%
pd.get_dummies(X,columns=['MARRIAGE']).head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 641       130000    2          3   28      0      0      0      0     -2
# 4678      170000    1          3   29      0      0      0      0      0
# 16004     180000    2          2   29      0      0      0      0      0
# 22974     210000    2          2   32     -2     -2     -2     -2     -2
# 17535     190000    2          3   45      0      0      0      0      0
#
#        PAY_6  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 641       -2  ...          0      2500      1000         0         0
# 4678       0  ...      33862      7200      7500      1200      1200
# 16004      0  ...      26176      1800      1800      1500      1056
# 22974     -2  ...          0       979       412         0         0
# 17535      0  ...      84811      3300      3331      3359      2663
#
#        PAY_AMT5  PAY_AMT6  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3
# 641           0         0        True       False       False
# 4678       1500      1300        True       False       False
# 16004       950      1000        True       False       False
# 22974         0         0       False        True       False
# 17535      2751      3000        True       False       False
#
# [5 rows x 25 columns]

# %%
X_encoded=pd.get_dummies(X,columns=['SEX','EDUCATION','MARRIAGE','PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6'])
X_encoded.head()
# Out:
#        LIMIT_BAL  AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 641       130000   28     100143      50456      50000          0          0
# 4678      170000   29     165027     168990     172307      35234      32869
# 16004     180000   29      25781      26000      26310      26662      26166
# 22974     210000   32        355        975        410          0          0
# 17535     190000   45      76433      78472      80548      81778      83082
#
#        BILL_AMT6  PAY_AMT1  PAY_AMT2  ...  PAY_5_7  PAY_6_-2  PAY_6_-1  \
# 641            0      2500      1000  ...    False      True     False
# 4678       33862      7200      7500  ...    False     False     False
# 16004      26176      1800      1800  ...    False     False     False
# 22974          0       979       412  ...    False      True     False
# 17535      84811      3300      3331  ...    False     False     False
#
#        PAY_6_0  PAY_6_2  PAY_6_3  PAY_6_4  PAY_6_5  PAY_6_6  PAY_6_7
# 641      False    False    False    False    False    False    False
# 4678      True    False    False    False    False    False    False
# 16004     True    False    False    False    False    False    False
# 22974    False    False    False    False    False    False    False
# 17535     True    False    False    False    False    False    False
#
# [5 rows x 81 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X_encoded,y,random_state=42)
X_train_scaled=scale(X_train)
X_test_scaled=scale(X_test)

# %%
clf_svm=SVC(random_state=42)
clf_svm.fit(X_train_scaled,y_train)
# Out:
# SVC(random_state=42)

# %%
plot_confusion_matrix(clf_svm,X_test_sclaed,y_test,values_format='d',display_labels=["Did not default","Defaulted"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 ConfusionMatrixDisplay(clf_svm,X_test_scaled,y_test,display_labels=["Did not default","Defaulted"])
#
# TypeError: ConfusionMatrixDisplay.__init__() takes 2 positional arguments but 4 positional arguments (and 1 keyword-only argument) were given
